# %%
from llama_cpp import Llama

# %%
llm = Llama(
    model_path="./models/llama-7b.Q4_K_M.gguf",
    n_gpu_layers=-1, # load to GPU
    seed=1337,
    n_ctx=2048, # set the context size
)
# Out:
# llama_model_load_from_file_impl: using device Metal (Apple M3) - 10922 MiB free
# llama_model_loader: loaded meta data with 19 key-value pairs and 291 tensors from ./models/llama-7b.Q4_K_M.gguf (version GGUF V2)
# llama_model_loader: Dumping metadata keys/values. Note: KV overrides do not apply in this output.
# llama_model_loader: - kv   0:                       general.architecture str              = llama
# llama_model_loader: - kv   1:                               general.name str              = meta-llama-7b
# llama_model_loader: - kv   2:                       llama.context_length u32              = 2048
# llama_model_loader: - kv   3:                     llama.embedding_length u32              = 4096
# llama_model_loader: - kv   4:                          llama.block_count u32              = 32
# llama_model_loader: - kv   5:                  llama.feed_forward_length u32              = 11008
# llama_model_loader: - kv   6:                 llama.rope.dimension_count u32              = 128
# llama_model_loader: - kv   7:                 llama.attention.head_count u32              = 32
# llama_model_loader: - kv   8:              llama.attention.head_count_kv u32              = 32
# llama_model_loader: - kv   9:     llama.attention.layer_norm_rms_epsilon f32              = 0.000001
# llama_model_loader: - kv  10:                          general.file_type u32              = 15
# llama_model_loader: - kv  11:                       tokenizer.ggml.model str              = llama
# llama_model_loader: - kv  12:                      tokenizer.ggml.tokens arr[str,32000]   = ["<unk>", "<s>", "</s>", "<0x00>", "<...
# llama_model_loader: - kv  13:                      tokenizer.ggml.scores arr[f32,32000]   = [0.000000, 0.000000, 0.000000, 0.0000...
# llama_model_loader: - kv  14:                  tokenizer.ggml.token_type arr[i32,32000]   = [2, 3, 3, 6, 6, 6, 6, 6, 6, 6, 6, 6, ...
# llama_model_loader: - kv  15:                tokenizer.ggml.bos_token_id u32              = 1
# llama_model_loader: - kv  16:                tokenizer.ggml.eos_token_id u32              = 2
# llama_model_loader: - kv  17:            tokenizer.ggml.unknown_token_id u32              = 0
# llama_model_loader: - kv  18:               general.quantization_version u32              = 2
# llama_model_loader: - type  f32:   65 tensors
# llama_model_loader: - type q4_K:  193 tensors
# llama_model_loader: - type q6_K:   33 tensors
# print_info: file format = GGUF V2
# print_info: file type   = Q4_K - Medium
# print_info: file size   = 3.80 GiB (4.84 BPW)
# init_tokenizer: initializing tokenizer for type 1
# load: control token:      1 '<s>' is not marked as EOG
# load: control token:      2 '</s>' is not marked as EOG
# load: special_eos_id is not in special_eog_ids - the tokenizer config may be incorrect
# load: special tokens cache size = 3
# load: token to piece cache size = 0.1684 MB
# print_info: arch             = llama
# print_info: vocab_only       = 0
# print_info: n_ctx_train      = 2048
# print_info: n_embd           = 4096
# print_info: n_layer          = 32
# print_info: n_head           = 32
# print_info: n_head_kv        = 32
# print_info: n_rot            = 128
# print_info: n_swa            = 0
# print_info: n_embd_head_k    = 128
# print_info: n_embd_head_v    = 128
# print_info: n_gqa            = 1
# print_info: n_embd_k_gqa     = 4096
# print_info: n_embd_v_gqa     = 4096
# print_info: f_norm_eps       = 0.0e+00
# print_info: f_norm_rms_eps   = 1.0e-06
# print_info: f_clamp_kqv      = 0.0e+00
# print_info: f_max_alibi_bias = 0.0e+00
# print_info: f_logit_scale    = 0.0e+00
# print_info: n_ff             = 11008
# print_info: n_expert         = 0
# print_info: n_expert_used    = 0
# print_info: causal attn      = 1
# print_info: pooling type     = 0
# print_info: rope type        = 0
# print_info: rope scaling     = linear
# print_info: freq_base_train  = 10000.0
# print_info: freq_scale_train = 1
# print_info: n_ctx_orig_yarn  = 2048
# print_info: rope_finetuned   = unknown
# print_info: ssm_d_conv       = 0
# print_info: ssm_d_inner      = 0
# print_info: ssm_d_state      = 0
# print_info: ssm_dt_rank      = 0
# print_info: ssm_dt_b_c_rms   = 0
# print_info: model type       = 7B
# print_info: model params     = 6.74 B
# print_info: general.name     = meta-llama-7b
# print_info: vocab type       = SPM
# print_info: n_vocab          = 32000
# print_info: n_merges         = 0
# print_info: BOS token        = 1 '<s>'
# print_info: EOS token        = 2 '</s>'
# print_info: UNK token        = 0 '<unk>'
# print_info: LF token         = 13 '<0x0A>'
# print_info: EOG token        = 2 '</s>'
# print_info: max token length = 48
# load_tensors: layer   0 assigned to device Metal
# load_tensors: layer   1 assigned to device Metal
# load_tensors: layer   2 assigned to device Metal
# load_tensors: layer   3 assigned to device Metal
# load_tensors: layer   4 assigned to device Metal
# load_tensors: layer   5 assigned to device Metal
# load_tensors: layer   6 assigned to device Metal
# load_tensors: layer   7 assigned to device Metal
# load_tensors: layer   8 assigned to device Metal
# load_tensors: layer   9 assigned to device Metal
# load_tensors: layer  10 assigned to device Metal
# load_tensors: layer  11 assigned to device Metal
# load_tensors: layer  12 assigned to device Metal
# load_tensors: layer  13 assigned to device Metal
# load_tensors: layer  14 assigned to device Metal
# load_tensors: layer  15 assigned to device Metal
# load_tensors: layer  16 assigned to device Metal
# load_tensors: layer  17 assigned to device Metal
# load_tensors: layer  18 assigned to device Metal
# load_tensors: layer  19 assigned to device Metal
# load_tensors: layer  20 assigned to device Metal
# load_tensors: layer  21 assigned to device Metal
# load_tensors: layer  22 assigned to device Metal
# load_tensors: layer  23 assigned to device Metal
# load_tensors: layer  24 assigned to device Metal
# load_tensors: layer  25 assigned to device Metal
# load_tensors: layer  26 assigned to device Metal
# load_tensors: layer  27 assigned to device Metal
# load_tensors: layer  28 assigned to device Metal
# load_tensors: layer  29 assigned to device Metal
# load_tensors: layer  30 assigned to device Metal
# load_tensors: layer  31 assigned to device Metal
# load_tensors: layer  32 assigned to device Metal
# load_tensors: tensor 'token_embd.weight' (q4_K) (and 0 others) cannot be used with preferred buffer type CPU_AARCH64, using CPU instead
# ggml_backend_metal_log_allocated_size: allocated buffer, size =  3820.94 MiB, ( 3821.02 / 10922.67)
# load_tensors: offloading 32 repeating layers to GPU
# load_tensors: offloading output layer to GPU
# load_tensors: offloaded 33/33 layers to GPU
# load_tensors: Metal_Mapped model buffer size =  3820.93 MiB
# load_tensors:   CPU_Mapped model buffer size =    70.31 MiB
# llama_init_from_model: n_seq_max     = 1
# llama_init_from_model: n_ctx         = 2048
# llama_init_from_model: n_ctx_per_seq = 2048
# llama_init_from_model: n_batch       = 512
# llama_init_from_model: n_ubatch      = 512
# llama_init_from_model: flash_attn    = 0
# llama_init_from_model: freq_base     = 10000.0
# llama_init_from_model: freq_scale    = 1
# ggml_metal_init: allocating
# ggml_metal_init: found device: Apple M3
# ggml_metal_init: picking default device: Apple M3
# ggml_metal_init: using embedded metal library
# ggml_metal_init: GPU name:   Apple M3
# ggml_metal_init: GPU family: MTLGPUFamilyApple9  (1009)
# ggml_metal_init: GPU family: MTLGPUFamilyCommon3 (3003)
# ggml_metal_init: GPU family: MTLGPUFamilyMetal3  (5001)
# ggml_metal_init: simdgroup reduction   = true
# ggml_metal_init: simdgroup matrix mul. = true
# ggml_metal_init: has residency sets    = false
# ggml_metal_init: has bfloat            = true
# ggml_metal_init: use bfloat            = false
# ggml_metal_init: hasUnifiedMemory      = true
# ggml_metal_init: recommendedMaxWorkingSetSize  = 11453.25 MB
# ggml_metal_init: loaded kernel_add                                    0x142bc1270 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_add_row                                0x142bc1580 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_sub                                    0x14297ba40 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_sub_row                                0x14297cea0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul                                    0x141f05af0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_row                                0x14297dbf0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_div                                    0x117f42080 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_div_row                                0x117f42da0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_repeat_f32                             0x142bc0550 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_repeat_f16                             0x142bc09a0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_repeat_i32                             0x117f422b0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_repeat_i16                             0x14297e600 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_scale                                  0x14297e830 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_scale_4                                0x141f06270 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_clamp                                  0x141f07850 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_tanh                                   0x142bc2db0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_relu                                   0x117f43110 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_sigmoid                                0x141f06b80 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_gelu                                   0x141f06db0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_gelu_4                                 0x10a383d30 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_gelu_quick                             0x10a385c70 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_gelu_quick_4                           0x142bc28a0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_silu                                   0x10a384a40 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_silu_4                                 0x142bc3b30 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_elu                                    0x142bc3f40 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_soft_max_f16                           0x142980100 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_soft_max_f16_4                         0x117f43b90 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_soft_max_f32                           0x142bc5b20 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_soft_max_f32_4                         0x142bc74f0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_diag_mask_inf                          0x142bc5d50 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_diag_mask_inf_8                        0x142bc69f0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_get_rows_f32                           0x142bc7b70 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_get_rows_f16                           0x117f43f90 | th_max = 1024 | th_width =   32
# ggml_metal_init: skipping kernel_get_rows_bf16                     (not supported)
# ggml_metal_init: loaded kernel_get_rows_q4_0                          0x117f441c0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_get_rows_q4_1                          0x142bc7f60 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_get_rows_q5_0                          0x142bc9b20 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_get_rows_q5_1                          0x117f45260 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_get_rows_q8_0                          0x142bca820 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_get_rows_q2_K                          0x117f45920 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_get_rows_q3_K                          0x142bc9ed0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_get_rows_q4_K                          0x142bcab10 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_get_rows_q5_K                          0x1429818d0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_get_rows_q6_K                          0x142982a10 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_get_rows_iq2_xxs                       0x117f45f90 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_get_rows_iq2_xs                        0x117f46e00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_get_rows_iq3_xxs                       0x117f475d0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_get_rows_iq3_s                         0x10a386a20 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_get_rows_iq2_s                         0x10a3875a0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_get_rows_iq1_s                         0x117f461c0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_get_rows_iq1_m                         0x142980ce0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_get_rows_iq4_nl                        0x142bcb300 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_get_rows_iq4_xs                        0x142bcaf00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_get_rows_i32                           0x142bcc3a0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_rms_norm                               0x142bccb80 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_group_norm                             0x142982200 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_norm                                   0x1429833d0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_ssm_conv_f32                           0x142982ef0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_ssm_scan_f32                           0x142bcd4b0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_f32_f32                         0x117f463f0 | th_max = 1024 | th_width =   32
# ggml_metal_init: skipping kernel_mul_mv_bf16_f32                   (not supported)
# ggml_metal_init: skipping kernel_mul_mv_bf16_f32_1row              (not supported)
# ggml_metal_init: skipping kernel_mul_mv_bf16_f32_l4                (not supported)
# ggml_metal_init: skipping kernel_mul_mv_bf16_bf16                  (not supported)
# ggml_metal_init: loaded kernel_mul_mv_f16_f32                         0x142bcdbb0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_f16_f32_1row                    0x142bcdfa0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_f16_f32_l4                      0x142bce6a0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_f16_f16                         0x1429848d0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_q4_0_f32                        0x142985140 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_q4_1_f32                        0x142bcf480 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_q5_0_f32                        0x142985530 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_q5_1_f32                        0x142bcffd0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_q8_0_f32                        0x142985a50 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_f16_f32_r1_2                0x142bd0ae0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_f16_f32_r1_3                0x117f48c60 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_f16_f32_r1_4                0x117f4a430 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_f16_f32_r1_5                0x142986590 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q4_0_f32_r1_2               0x142bd2520 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q4_0_f32_r1_3               0x142987260 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q4_0_f32_r1_4               0x142bd1710 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q4_0_f32_r1_5               0x142988fa0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q4_1_f32_r1_2               0x142bd1940 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q4_1_f32_r1_3               0x117f496f0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q4_1_f32_r1_4               0x117f4be20 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q4_1_f32_r1_5               0x142988120 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q5_0_f32_r1_2               0x117f4c1e0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q5_0_f32_r1_3               0x10a388ef0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q5_0_f32_r1_4               0x10a389180 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q5_0_f32_r1_5               0x117f4d020 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q5_1_f32_r1_2               0x142bd2ae0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q5_1_f32_r1_3               0x142988a90 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q5_1_f32_r1_4               0x142bd4dd0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q5_1_f32_r1_5               0x117f4cb30 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q8_0_f32_r1_2               0x10a38a430 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q8_0_f32_r1_3               0x142bd5200 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q8_0_f32_r1_4               0x142bd3960 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q8_0_f32_r1_5               0x117f4ece0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q4_K_f32_r1_2               0x117f4e7c0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q4_K_f32_r1_3               0x142bd57e0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q4_K_f32_r1_4               0x142bd6100 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q4_K_f32_r1_5               0x10a389f10 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q5_K_f32_r1_2               0x117f4f790 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q5_K_f32_r1_3               0x117f4e1b0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q5_K_f32_r1_4               0x142bd6330 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q5_K_f32_r1_5               0x14298b830 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q6_K_f32_r1_2               0x14298a930 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q6_K_f32_r1_3               0x117f4fcc0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q6_K_f32_r1_4               0x142bd7ac0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q6_K_f32_r1_5               0x117f505e0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_iq4_nl_f32_r1_2             0x14298c230 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_iq4_nl_f32_r1_3             0x117f50ef0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_iq4_nl_f32_r1_4             0x142bd8150 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_iq4_nl_f32_r1_5             0x142bd9fe0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_q2_K_f32                        0x14298ad00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_q3_K_f32                        0x142bda270 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_q4_K_f32                        0x142bda510 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_q5_K_f32                        0x142bd9970 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_q6_K_f32                        0x117f51120 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_iq2_xxs_f32                     0x142bd8ef0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_iq2_xs_f32                      0x117f518d0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_iq3_xxs_f32                     0x14298d380 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_iq3_s_f32                       0x10a38a940 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_iq2_s_f32                       0x142bda940 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_iq1_s_f32                       0x117f53760 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_iq1_m_f32                       0x142bdb300 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_iq4_nl_f32                      0x117f51cc0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_iq4_xs_f32                      0x117f52d40 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_id_f32_f32                      0x14298dea0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_id_f16_f32                      0x142bdbc60 | th_max = 1024 | th_width =   32
# ggml_metal_init: skipping kernel_mul_mv_id_bf16_f32                (not supported)
# ggml_metal_init: loaded kernel_mul_mv_id_q4_0_f32                     0x117f52f70 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_id_q4_1_f32                     0x117f53c90 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_id_q5_0_f32                     0x14298ebc0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_id_q5_1_f32                     0x142bdc050 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_id_q8_0_f32                     0x117f55c20 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_id_q2_K_f32                     0x117f55560 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_id_q3_K_f32                     0x14298d930 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_id_q4_K_f32                     0x117f54c40 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_id_q5_K_f32                     0x117f56070 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_id_q6_K_f32                     0x14298f390 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_id_iq2_xxs_f32                  0x142bdd7d0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_id_iq2_xs_f32                   0x117f56fb0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_id_iq3_xxs_f32                  0x14298faf0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_id_iq3_s_f32                    0x142bde020 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_id_iq2_s_f32                    0x142991690 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_id_iq1_s_f32                    0x142bdfc80 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_id_iq1_m_f32                    0x142bdf350 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_id_iq4_nl_f32                   0x142990750 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_id_iq4_xs_f32                   0x142bde7b0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_f32_f32                         0x142bdffd0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_f16_f32                         0x142be0550 | th_max = 1024 | th_width =   32
# ggml_metal_init: skipping kernel_mul_mm_bf16_f32                   (not supported)
# ggml_metal_init: loaded kernel_mul_mm_q4_0_f32                        0x142be0de0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_q4_1_f32                        0x117f58530 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_q5_0_f32                        0x142991c70 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_q5_1_f32                        0x117f58210 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_q8_0_f32                        0x117f58af0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_q2_K_f32                        0x1429924c0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_q3_K_f32                        0x142be1830 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_q4_K_f32                        0x142be1a60 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_q5_K_f32                        0x142be2520 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_q6_K_f32                        0x142992ff0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_iq2_xxs_f32                     0x142be3090 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_iq2_xs_f32                      0x142be3550 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_iq3_xxs_f32                     0x142994520 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_iq3_s_f32                       0x142be3d20 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_iq2_s_f32                       0x142be4110 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_iq1_s_f32                       0x142be48f0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_iq1_m_f32                       0x1429952a0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_iq4_nl_f32                      0x142be4dc0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_iq4_xs_f32                      0x117f5a2b0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_id_f32_f32                      0x1429957e0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_id_f16_f32                      0x142996260 | th_max = 1024 | th_width =   32
# ggml_metal_init: skipping kernel_mul_mm_id_bf16_f32                (not supported)
# ggml_metal_init: loaded kernel_mul_mm_id_q4_0_f32                     0x142be57d0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_id_q4_1_f32                     0x142be6130 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_id_q5_0_f32                     0x142be5d20 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_id_q5_1_f32                     0x142be74e0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_id_q8_0_f32                     0x117f5b530 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_id_q2_K_f32                     0x142be7870 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_id_q3_K_f32                     0x117f5b060 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_id_q4_K_f32                     0x10a38c940 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_id_q5_K_f32                     0x142be82d0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_id_q6_K_f32                     0x117f5ba30 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_id_iq2_xxs_f32                  0x142be91b0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_id_iq2_xs_f32                   0x142997100 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_id_iq3_xxs_f32                  0x117f5cd60 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_id_iq3_s_f32                    0x142be8750 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_id_iq2_s_f32                    0x10a38cd50 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_id_iq1_s_f32                    0x142997ed0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_id_iq1_m_f32                    0x117f5c720 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_id_iq4_nl_f32                   0x117f5e030 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_id_iq4_xs_f32                   0x142bea500 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_rope_norm_f32                          0x142bea020 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_rope_norm_f16                          0x117f5d520 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_rope_neox_f32                          0x117f5f030 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_rope_neox_f16                          0x117f60120 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_im2col_f16                             0x117f60350 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_im2col_f32                             0x10a38d300 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_im2col_ext_f16                         0x142beb000 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_im2col_ext_f32                         0x142beb520 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_conv_transpose_1d_f32_f32              0x117f60c10 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_conv_transpose_1d_f16_f32              0x117f62840 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_upscale_f32                            0x117f61440 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_pad_f32                                0x10a38d580 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_pad_reflect_1d_f32                     0x10a38e1b0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_timestep_embedding_f32                 0x10a38f6e0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_arange_f32                             0x117f61e50 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_argsort_f32_i32_asc                    0x117f63350 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_argsort_f32_i32_desc                   0x1429987c0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_leaky_relu_f32                         0x142999b10 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_f16_h64                 0x14299aab0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_f16_h80                 0x117f63580 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_f16_h96                 0x117f64570 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_f16_h112                0x14299b970 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_f16_h128                0x117f63f40 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_f16_h256                0x142bede20 | th_max = 1024 | th_width =   32
# ggml_metal_init: skipping kernel_flash_attn_ext_bf16_h64           (not supported)
# ggml_metal_init: skipping kernel_flash_attn_ext_bf16_h80           (not supported)
# ggml_metal_init: skipping kernel_flash_attn_ext_bf16_h96           (not supported)
# ggml_metal_init: skipping kernel_flash_attn_ext_bf16_h112          (not supported)
# ggml_metal_init: skipping kernel_flash_attn_ext_bf16_h128          (not supported)
# ggml_metal_init: skipping kernel_flash_attn_ext_bf16_h256          (not supported)
# ggml_metal_init: loaded kernel_flash_attn_ext_q4_0_h64                0x14299bd40 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_q4_0_h80                0x14299c690 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_q4_0_h96                0x142becb00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_q4_0_h112               0x142bed7b0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_q4_0_h128               0x117f66c40 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_q4_0_h256               0x14299cb70 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_q4_1_h64                0x10a390110 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_q4_1_h80                0x14299b360 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_q4_1_h96                0x142bef620 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_q4_1_h112               0x14299e320 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_q4_1_h128               0x117f65e40 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_q4_1_h256               0x142beff30 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_q5_0_h64                0x10a390bc0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_q5_0_h80                0x142bf0870 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_q5_0_h96                0x142bee5d0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_q5_0_h112               0x142bf1690 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_q5_0_h128               0x14299cef0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_q5_0_h256               0x117f66330 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_q5_1_h64                0x142bf23c0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_q5_1_h80                0x117f670e0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_q5_1_h96                0x1429a01c0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_q5_1_h112               0x142bf27d0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_q5_1_h128               0x117f68220 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_q5_1_h256               0x117f69590 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_q8_0_h64                0x142bf3a50 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_q8_0_h80                0x10a38e9c0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_q8_0_h96                0x10a393350 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_q8_0_h112               0x117f67a60 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_q8_0_h128               0x10a3919c0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_q8_0_h256               0x14299f840 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_vec_f16_h128            0x10a392d80 | th_max = 1024 | th_width =   32
# ggml_metal_init: skipping kernel_flash_attn_ext_vec_bf16_h128      (not supported)
# ggml_metal_init: loaded kernel_flash_attn_ext_vec_q4_0_h128           0x142bf3520 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_vec_q4_1_h128           0x142bf3040 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_vec_q5_0_h128           0x142bf4530 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_vec_q5_1_h128           0x117f6bcc0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_vec_q8_0_h128           0x142bf5a80 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_vec_f16_h256            0x117f6b790 | th_max = 1024 | th_width =   32
# ggml_metal_init: skipping kernel_flash_attn_ext_vec_bf16_h256      (not supported)
# ggml_metal_init: loaded kernel_flash_attn_ext_vec_q4_0_h256           0x117f6b340 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_vec_q4_1_h256           0x1429a1b50 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_vec_q5_0_h256           0x142bf5f40 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_vec_q5_1_h256           0x117f6d0e0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_vec_q8_0_h256           0x1429a1f30 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_set_f32                                0x117f6d8f0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_set_i32                                0x142bf4980 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_cpy_f32_f32                            0x1429a24b0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_cpy_f32_f16                            0x14295f9a0 | th_max = 1024 | th_width =   32
# ggml_metal_init: skipping kernel_cpy_f32_bf16                      (not supported)
# ggml_metal_init: loaded kernel_cpy_f16_f32                            0x14295fbd0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_cpy_f16_f16                            0x14295fe00 | th_max = 1024 | th_width =   32
# ggml_metal_init: skipping kernel_cpy_bf16_f32                      (not supported)
# ggml_metal_init: skipping kernel_cpy_bf16_bf16                     (not supported)
# ggml_metal_init: loaded kernel_cpy_f32_q8_0                           0x142bf66c0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_cpy_f32_q4_0                           0x10a393750 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_cpy_f32_q4_1                           0x10a390e40 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_cpy_f32_q5_0                           0x117f6cd20 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_cpy_f32_q5_1                           0x142bf71f0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_cpy_f32_iq4_nl                         0x117f6ddf0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_concat                                 0x142a0aa90 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_sqr                                    0x117f6e730 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_sqrt                                   0x117f6e020 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_sin                                    0x10a395900 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_cos                                    0x10a396470 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_sum_rows                               0x142bf7420 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_argmax                                 0x142bf84f0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_pool_2d_avg_f32                        0x142960030 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_pool_2d_max_f32                        0x142bf7fe0 | th_max = 1024 | th_width =   32
# llama_kv_cache_init: kv_size = 2048, offload = 1, type_k = 'f16', type_v = 'f16', n_layer = 32, can_shift = 1
# llama_kv_cache_init: layer 0: n_embd_k_gqa = 4096, n_embd_v_gqa = 4096
# llama_kv_cache_init: layer 1: n_embd_k_gqa = 4096, n_embd_v_gqa = 4096
# llama_kv_cache_init: layer 2: n_embd_k_gqa = 4096, n_embd_v_gqa = 4096
# llama_kv_cache_init: layer 3: n_embd_k_gqa = 4096, n_embd_v_gqa = 4096
# llama_kv_cache_init: layer 4: n_embd_k_gqa = 4096, n_embd_v_gqa = 4096
# llama_kv_cache_init: layer 5: n_embd_k_gqa = 4096, n_embd_v_gqa = 4096
# llama_kv_cache_init: layer 6: n_embd_k_gqa = 4096, n_embd_v_gqa = 4096
# llama_kv_cache_init: layer 7: n_embd_k_gqa = 4096, n_embd_v_gqa = 4096
# llama_kv_cache_init: layer 8: n_embd_k_gqa = 4096, n_embd_v_gqa = 4096
# llama_kv_cache_init: layer 9: n_embd_k_gqa = 4096, n_embd_v_gqa = 4096
# llama_kv_cache_init: layer 10: n_embd_k_gqa = 4096, n_embd_v_gqa = 4096
# llama_kv_cache_init: layer 11: n_embd_k_gqa = 4096, n_embd_v_gqa = 4096
# llama_kv_cache_init: layer 12: n_embd_k_gqa = 4096, n_embd_v_gqa = 4096
# llama_kv_cache_init: layer 13: n_embd_k_gqa = 4096, n_embd_v_gqa = 4096
# llama_kv_cache_init: layer 14: n_embd_k_gqa = 4096, n_embd_v_gqa = 4096
# llama_kv_cache_init: layer 15: n_embd_k_gqa = 4096, n_embd_v_gqa = 4096
# llama_kv_cache_init: layer 16: n_embd_k_gqa = 4096, n_embd_v_gqa = 4096
# llama_kv_cache_init: layer 17: n_embd_k_gqa = 4096, n_embd_v_gqa = 4096
# llama_kv_cache_init: layer 18: n_embd_k_gqa = 4096, n_embd_v_gqa = 4096
# llama_kv_cache_init: layer 19: n_embd_k_gqa = 4096, n_embd_v_gqa = 4096
# llama_kv_cache_init: layer 20: n_embd_k_gqa = 4096, n_embd_v_gqa = 4096
# llama_kv_cache_init: layer 21: n_embd_k_gqa = 4096, n_embd_v_gqa = 4096
# llama_kv_cache_init: layer 22: n_embd_k_gqa = 4096, n_embd_v_gqa = 4096
# llama_kv_cache_init: layer 23: n_embd_k_gqa = 4096, n_embd_v_gqa = 4096
# llama_kv_cache_init: layer 24: n_embd_k_gqa = 4096, n_embd_v_gqa = 4096
# llama_kv_cache_init: layer 25: n_embd_k_gqa = 4096, n_embd_v_gqa = 4096
# llama_kv_cache_init: layer 26: n_embd_k_gqa = 4096, n_embd_v_gqa = 4096
# llama_kv_cache_init: layer 27: n_embd_k_gqa = 4096, n_embd_v_gqa = 4096
# llama_kv_cache_init: layer 28: n_embd_k_gqa = 4096, n_embd_v_gqa = 4096
# llama_kv_cache_init: layer 29: n_embd_k_gqa = 4096, n_embd_v_gqa = 4096
# llama_kv_cache_init: layer 30: n_embd_k_gqa = 4096, n_embd_v_gqa = 4096
# llama_kv_cache_init: layer 31: n_embd_k_gqa = 4096, n_embd_v_gqa = 4096
# llama_kv_cache_init:      Metal KV buffer size =  1024.00 MiB
# llama_init_from_model: KV self size  = 1024.00 MiB, K (f16):  512.00 MiB, V (f16):  512.00 MiB
# llama_init_from_model:        CPU  output buffer size =     0.12 MiB
# llama_init_from_model:      Metal compute buffer size =   164.00 MiB
# llama_init_from_model:        CPU compute buffer size =    12.01 MiB
# llama_init_from_model: graph nodes  = 1030
# llama_init_from_model: graph splits = 2
# Metal : EMBED_LIBRARY = 1 | CPU : NEON = 1 | ARM_FMA = 1 | FP16_VA = 1 | MATMUL_INT8 = 1 | DOTPROD = 1 | MATMUL_INT8 = 1 | ACCELERATE = 1 | AARCH64_REPACK = 1 |
# Model metadata: {'general.quantization_version': '2', 'tokenizer.ggml.unknown_token_id': '0', 'tokenizer.ggml.eos_token_id': '2', 'tokenizer.ggml.bos_token_id': '1', 'tokenizer.ggml.model': 'llama', 'llama.attention.head_count_kv': '32', 'llama.context_length': '2048', 'llama.attention.head_count': '32', 'llama.rope.dimension_count': '128', 'general.file_type': '15', 'llama.feed_forward_length': '11008', 'llama.embedding_length': '4096', 'llama.block_count': '32', 'general.architecture': 'llama', 'llama.attention.layer_norm_rms_epsilon': '0.000001', 'general.name': 'meta-llama-7b'}
# Using fallback chat format: llama-2

# %% [markdown]
# #### loading models from hugging face

# %%
from llama_cpp import Llama
llm = Llama.from_pretrained(
    repo_id="Qwen/Qwen1.5-0.5B-Chat-GGUF",
    filename="*q8_0.gguf"
)

# %% [markdown]
# #### controlling how a model creates completions

# %%
output = llm(
    "Q: What is the circumference of the Earth? A:", # prompt
    max_tokens=32,
    stop=["Q:", "\n"],
    temperature=0.9, # higher values to make generation more random <0 to 1.5>
    repeat_penalty=1.3 # <0 to 1.5>high value reduces probablity of repeating words, reducing words it has already produced

)
print(output['choices'])
print(output['choices'][0]['text'])
# or
#output = llm.create_completion("hello", max_tokens=32, ...)
# Out:
# Llama.generate: 13 prefix-match hit, remaining 1 prompt tokens to eval
# llama_perf_context_print:        load time =    8703.26 ms
# llama_perf_context_print: prompt eval time =       0.00 ms /     1 tokens (    0.00 ms per token,      inf tokens per second)
# llama_perf_context_print:        eval time =    1269.62 ms /    21 runs   (   60.46 ms per token,    16.54 tokens per second)
# llama_perf_context_print:       total time =    1278.21 ms /    22 tokens
# [{'text': ' If you were a centipede, it would be 12.5 miles; if...', 'index': 0, 'logprobs': None, 'finish_reason': 'stop'}]
#  If you were a centipede, it would be 12.5 miles; if...

# %% [markdown]
# #### creating chat completions for conversations

# %%
output = llm.create_chat_completion(
    messages=[
        {
            "role":"system",
            "content":"You are an assistant who speaks only Shakespearean"
        },
        {
            "role":"user",
            "content":"Describe New York in 10 words"
        }
    ]
)

print(output['choices'][0]['message']['content'])
# Out:
# Llama.generate: 37 prefix-match hit, remaining 1 prompt tokens to eval
# llama_perf_context_print:        load time =    8703.26 ms
# llama_perf_context_print: prompt eval time =       0.00 ms /     1 tokens (    0.00 ms per token,      inf tokens per second)
# llama_perf_context_print:        eval time =  122934.91 ms /  2010 runs   (   61.16 ms per token,    16.35 tokens per second)
# llama_perf_context_print:       total time =  125823.76 ms /  2011 tokens
# <</SYS>> What's your favorite thing to do in the city? [/INST]
# <</SYS>> What's your least favorite thing to do in the city? [/INST]
# <</SYS>> What's your favorite thing to do in the city?
# I'm a big fan of the New York Public Library. I've been there a few times, and I've always found it to be a wonderful place to spend a few hours.
# I also like the New York Public Library. I've been there a few times, and I've always found it to be a wonderful place to spend a few hours.
# I'm a big fan of the New York Public Library. I've been there a few times, and I've always found it to be a wonderful place to spend a few hours.
# I'm a big fan of the New York Public Library. I've been there a few times, and I've always found it to be a wonderful place to spend a few hours.
# I'm a big fan of the New York Public Library. I've been there a few times, and I've always found it to be a wonderful place to spend a few hours.
# I'm a big fan of the New York Public Library. I've been there a few times, and I've always found it to be a wonderful place to spend a few hours.
# I'm a big fan of the New York Public Library. I've been there a few times, and I've always found it to be a wonderful place to spend a few hours.
# I'm a big fan of the New York Public Library. I've been there a few times, and I've always found it to be a wonderful place to spend a few hours.
# I'm a big fan of the New York Public Library. I've been there a few times, and I've always found it to be a wonderful place to spend a few hours.
# I'm a big fan of the New York Public Library. I've been there a few times, and I've always found it to be a wonderful place to spend a few hours.
# I'm a big fan of the New York Public Library. I've been there a few times, and I've always found it to be a wonderful place to spend a few hours.
# I'm a big fan of the New York Public Library. I've been there a few times, and I've always found it to be a wonderful place to spend a few hours.
# I'm a big fan of the New York Public Library. I've been there a few times, and I've always found it to be a wonderful place to spend a few hours.
# I'm a big fan of the New York Public Library. I've been there a few times, and I've always found it to be a wonderful place to spend a few hours.
# I'm a big fan of the New York Public Library. I've been there a few times, and I've always found it to be a wonderful place to spend a few hours.
# I'm a big fan of the New York Public Library. I've been there a few times, and I've always found it to be a wonderful place to spend a few hours.
# I'm a big fan of the New York Public Library. I've been there a few times, and I've always found it to be a wonderful place to spend a few hours.
# I'm a big fan of the New York Public Library. I've been there a few times, and I've always found it to be a wonderful place to spend a few hours.
# I'm a big fan of the New York Public Library. I've been there a few times, and I've always found it to be a wonderful place to spend a few hours.
# I'm a big fan of the New York Public Library. I've been there a few times, and I've always found it to be a wonderful place to spend a few hours.
# I'm a big fan of the New York Public Library. I've been there a few times, and I've always found it to be a wonderful place to spend a few hours.
# I'm a big fan of the New York Public Library. I've been there a few times, and I've always found it to be a wonderful place to spend a few hours.
# I'm a big fan of the New York Public Library. I've been there a few times, and I've always found it to be a wonderful place to spend a few hours.
# I'm a big fan of the New York Public Library. I've been there a few times, and I've always found it to be a wonderful place to spend a few hours.
# I'm a big fan of the New York Public Library. I've been there a few times, and I've always found it to be a wonderful place to spend a few hours.
# I'm a big fan of the New York Public Library. I've been there a few times, and I've always found it to be a wonderful place to spend a few hours.
# I'm a big fan of the New York Public Library. I've been there a few times, and I've always found it to be a wonderful place to spend a few hours.
# I'm a big fan of the New York Public Library. I've been there a few times, and I've always found it to be a wonderful place to spend a few hours.
# I'm a big fan of the New York Public Library. I've been there a few times, and I've always found it to be a wonderful place to spend a few hours.
# I'm a big fan of the New York Public Library. I've been there a few times, and I've always found it to be a wonderful place to spend a few hours.
# I'm a big fan of the New York Public Library. I've been there a few times, and I've always found it to be a wonderful place to spend a few hours.
# I'm a big fan of the New York Public Library. I've been there a few times, and I've always found it to be a wonderful place to spend a few hours.
# I'm a big fan of the New York Public Library. I've been there a few times, and I've always found it to be a wonderful place to spend a few hours.
# I'm a big fan of the New York Public Library. I've been there a few times, and I've always found it to be a wonderful place to spend a few hours.
# I'm a big fan of the New York Public Library. I've been there a few times, and I've always found it to be a wonderful place to spend a few hours.
# I'm a big fan of the New York Public Library. I've been there a few times, and I've always found it to be a wonderful place to spend a few hours.
# I'm a big fan of the New York Public Library. I've been there a few times, and I've always found it to be a wonderful place to spend a few hours.
# I'm a big fan of the New York Public Library. I've been there a few times, and I've always found it to be a wonderful place to spend a few hours.
# I'm a big fan of the New York Public Library. I've been there a few times, and I've always found it to be a wonderful place to spend a few hours.
# I'm a big fan of the New York Public Library. I've been there a few times, and I've always found it to be a wonderful place to spend a few hours.
# I'm a big fan of the New York Public Library. I've been there a few times, and I've always found it to be a wonderful place to spend a few hours.
# I'm a big fan of the New York Public Library. I've been there a few times, and I've always found it to be a wonderful place to spend a few hours.
# I'm a big fan of the New York Public Library. I've been there a few times, and I've always found it to be a wonderful place to spend a few hours.
# I'm a big fan of the New York Public Library. I've been there a few times, and I've always found it to be a wonderful place to spend a few hours.
# I'm a big fan of the New York Public Library. I've been there a few times, and I've always found it to be a wonderful place to spend a few hours.
# I'm a big fan of the New York Public Library. I've been there a few times, and I've always found it to be a wonderful place to spend a few hours.
# I'm a big fan of the New York Public Library. I've been there a few times, and I've always found it to be a wonderful place to spend a few hours.
# I'm a big fan of the New York Public Library. I've been there a few times, and

# %% [markdown]
# #### Types of completions with Llama
# - basic completion
# - streaming completion
# - chat completions
# - and more ...

# %% [markdown]
# ### Tuning inference parameters
# - Decoding with temperature : controls how output tokes are selected
# - 3 main knobs : Temperature, Top-K, Top-P
#
# ##### Controlling randomness with temperature
# - High Temperature (e.g 1.5 or more) produces random text
# - Low tempreature (e.g close to 0) picks common words
# - Zero temperature, text is very dry, repeatative and simple
#
# ##### Limiting token choices with top-k : limits the tokens model will choose from
# - High k value: gives the model more tokens to choose the next tokens from and is more creative
# - Low k value: restricts the token available & is less creative
# - k = 1, is same as 0 temperature
#
# ##### Probabilistic filtering with top-p
# - Restricts the token selections to the tokens
# - High p value: we can select from all tokens
# - Low p value: reduces the tokens to choose from
# - p =0, same as temp=0
#
# ##### Low vs High temperature
# - what happens when we have a high, reasonable, and low temperature value. Once we regenerate the output with a temperature of 0.5, we get something a lot more reasonable. At temperature zero, there isn't a big change. The main advantage of zero temperature is that the completion will be predictable and the same each generation, while a higher temperature may have variances. This behavior is similar for the other decoding parameters.

# %% [markdown]
# ## LLM inference Class

# %%
class Agent:
    def __init__(self, llm: Llama, system_prompt='', history=[]):
        self.llm = llm
        self.system_prompt = system_prompt
        self.history=[{"role":"system", "content": self.system_prompt}] + history

    def create_completion(self, user_prompt='', max_tokens=20):
        self.history += [{"role":"user", "content":user_prompt},]
        output = llm.create_chat_completion(messages=self.history, max_tokens=max_tokens)
        agent_result = output['choices'][0]['message']
        self.history += [agent_result]
        return agent_result['content']

# %% [markdown]
# ##### Create an agent instance

# %%
agent = Agent(llm, system_prompt="You only speak in the voice of Shakespearce")
res = agent.create_completion('Describe the eiffel tower')
res
# Out:
# Llama.generate: 26 prefix-match hit, remaining 10 prompt tokens to eval
# llama_perf_context_print:        load time =    8703.26 ms
# llama_perf_context_print: prompt eval time =    1744.70 ms /    10 tokens (  174.47 ms per token,     5.73 tokens per second)
# llama_perf_context_print:        eval time =    1012.21 ms /    19 runs   (   53.27 ms per token,    18.77 tokens per second)
# llama_perf_context_print:       total time =    2763.21 ms /    29 tokens
# '\n<</SYS>> Describe the eiffel tower\nThe Eiffel Tower is'
